# %% [markdown]
# # 01 Variables

# %%
# 1. Create variable pi with value 22/7 and check its data type
pi = 22 / 7
print("Data type of pi:", type(pi))
# Out:
# Data type of pi: <class 'float'>

# %%
# 2. Create variable 'for' with value 4 
# for = 4  # This causes SyntaxError
for_ = 4
print("Value of for_:", for_) 

# Reason: 'for' is a reserved keyword in Python for loops
# Out:
# Value of for_: 4

# %%
# 3. Store principal, rate, time and calculate Simple Interest: SI = P*R*T/100
p = 1000  # principal amount
r = 5     # rate of interest
t = 3     # time
si = (p * r * t) / 100
print("Simple Interest:", si)
# Out:
# Simple Interest: 150.0
